# %%
# Create New Jupyter Notebookmp; matplotlib
# Import pandas, numpy & matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io 
# %cd "C:\Users\sujit\Downloads\PGA 26 datasets\Churn"
# Out:
# C:\Users\sujit\Downloads\PGA 26 datasets\Churn

# %%
# Import dataset &'WA_Fn-UseC_-Telco-Customer-Churn''
churn=pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# head, tail, shape, dtypes, columns, describe
pd.set_option('display.max_columns',21)
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
churn.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 7038           No              Yes         Yes         Yes             Yes
# ...

# %%
churn.shape
# Out:
# (7043, 21)

# %%
churn.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
churn.TotalCharges=pd.to_numeric(churn.TotalCharges,errors='coerce')

# %%
churn.SeniorCitizen=churn.SeniorCitizen.astype('object')

# %%
churn.describe().T
# Out:
#                  count         mean          std    min     25%       50%  \
# tenure          7043.0    32.371149    24.559481   0.00    9.00    29.000
# MonthlyCharges  7043.0    64.761692    30.090047  18.25   35.50    70.350
# TotalCharges    7032.0  2283.300441  2266.771362  18.80  401.45  1397.475
#
#                       75%      max
# tenure            55.0000    72.00
# MonthlyCharges    89.8500   118.75
# TotalCharges    3794.7375  8684.80

# %% [markdown]
# # Handling Missing Values

# %%
churn.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
churn.TotalCharges=churn.TotalCharges.fillna(churn.TotalCharges.median())

# %% [markdown]
# # Exploratory Data Analysis

# %%
# histogram, boxplot & density curve - MonthlyCharges 
plt.figure(figsize=(10,15))

plt.subplot(3,1,1)
plt.hist(churn.MonthlyCharges)
plt.title('Histogram of Monthly_charges')
plt.xlabel('Monthlycharges')
plt.ylabel('Frequency')

plt.subplot(3,1,2)
plt.boxplot(churn.MonthlyCharges,vert=False)
plt.title('Boxplot of Monthly_charges')
plt.xlabel('Monthlycharges')

plt.subplot(3,1,3)
sns.kdeplot(churn.MonthlyCharges)
plt.title('Density curve of Monthly_charges')
plt.xlabel('Monthlycharges')

plt.show()

# %%
# histogram, boxplot & density curve - tenure
plt.figure(figsize=(10,15))

plt.subplot(3,1,1)
plt.hist(churn.tenure)
plt.title('Histogram of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')

plt.subplot(3,1,2)
plt.boxplot(churn.tenure,vert=False)
plt.title('Boxplot of Tenure')
plt.xlabel('Tenure')

plt.subplot(3,1,3)
sns.kdeplot(churn.tenure)
plt.title('Density curve of Tenure')
plt.xlabel('Tenure')

plt.show()

# %%
# histogram, boxplot & density curve - TotalCharges 
plt.figure(figsize=(10,15))

plt.subplot(3,1,1)
plt.hist(churn.TotalCharges)
plt.title('Histogram of Total_charges')
plt.xlabel('Totalcharges')
plt.ylabel('Frequency')

plt.subplot(3,1,2)
plt.boxplot(churn.TotalCharges,vert=False)
plt.title('Boxplot of Total_charges')
plt.xlabel('Total charges')

plt.subplot(3,1,3)
sns.kdeplot(churn.TotalCharges)
plt.title('Density curve of Total_charges')
plt.xlabel('Total charges')

plt.show()

# %%
# Frequency Counts of following variables
# Churn, gender, SeniorCitizen, PaymentMethod
plt.figure(figsize=(15,10))
churn.Churn.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,explode=[0.05,0],shadow=True,colors=('red','yellow'))
plt.title('Frequncy Counts of Churn in %')
plt.legend(title='Churn',loc='best')
plt.show()

# %%
plt.figure(figsize=(15,10))
churn.gender.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,explode=[0.05,0],shadow=True,colors=('teal','cyan'))
plt.title('Frequncy Counts of Gender in %')
plt.legend(title='Gender',loc='best')
plt.show()

# %%
plt.figure(figsize=(15,10))
churn.SeniorCitizen.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,explode=[0.1,0],
                                        shadow=True,colors=('skyblue','violet'))
plt.title('Frequncy Counts Senior Citizen in %')
plt.legend(title='Senior_Citizen',loc='best')
plt.show()

# %%
plt.figure(figsize=(15,10))
churn.PaymentMethod.value_counts().plot(kind='pie',autopct='%.1f%%',legend=True,explode=[0.07,0,0,0],
                                        shadow=True,colors=('maroon','tan','olive','indigo'))
plt.title('Frequncy Counts of Payment Method in %')
plt.legend(title='Payment_Method',loc='best')
plt.show()

# %%
# Frequency Counts of following variables
# Churn, gender, SeniorCitizen, PaymentMethod
a=churn[['Churn','gender', 'SeniorCitizen','PaymentMethod']]

# %%
for i in a.columns:
    freq=a[i].value_counts(dropna=False)
    print(freq)
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
# Cross Tabulation
# Churn & gender
print(pd.crosstab(churn.Churn,churn.gender))
a=pd.crosstab(churn.Churn,churn.gender).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Gender',stacked=True,figsize=(10,8),
                                             color=('silver','gold'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)
# Out:
# gender  Female  Male
# Churn
# No        2549  2625
# Yes        939   930

# %%
# Churn & InternetService
print(pd.crosstab(churn.Churn,churn.InternetService))
a=pd.crosstab(churn.Churn,churn.InternetService).plot(kind='bar',
                                             title='Cross Tabulation for Churn & Internet_Service',stacked=True,figsize=(10,8),
                                             color=('orange','salmon','crimson'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)
# Out:
# InternetService   DSL  Fiber optic    No
# Churn
# No               1962         1799  1413
# Yes               459         1297   113

# %%
# gender & PaymentMethod
print(pd.crosstab(churn.gender,churn.PaymentMethod))
a=pd.crosstab(churn.gender,churn.PaymentMethod).plot(kind='bar',
                                             title='Cross Tabulation for Gender & Payment_Method',stacked=True,figsize=(10,8),
                                             color=('chocolate','springgreen','brown','aqua'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.ylabel('Frequency')
    plt.xticks(rotation=0)
    plt.legend(title='Payment_Method',loc='best')
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# gender
# Female                               788                      752
# Male                                 756                      770
#
# PaymentMethod  Electronic check  Mailed check
# gender
# Female                     1170           778
# Male                       1195           834

# %%
# groupby()
# Average MonthlyCharges by gender
print(churn.MonthlyCharges.groupby(churn.gender).mean())
plt.figure(figsize=(10,6))
a=round(churn.MonthlyCharges.groupby(churn.gender).mean(),
        1).plot(kind='bar',title='Average MonthlyCharges by gender',color=('red','violet'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Gender')
    plt.ylabel('Average Monthly Charges')
# Out:
# gender
# Female    65.204243
# Male      64.327482
# Name: MonthlyCharges, dtype: float64

# %%
# Average tenure by SeniorCitizen
print(churn.tenure.groupby(churn.SeniorCitizen).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.SeniorCitizen).mean(),
        1).plot(kind='bar',title='Average Tenure by SeniorCitizen',color=('cyan','salmon'))
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Senior_Citizen')
    plt.ylabel('Average Tenure')
# Out:
# SeniorCitizen
# 0    32.192171
# 1    33.295972
# Name: tenure, dtype: float64

# %%
# Average tenure by PaymentMethod
print(churn.tenure.groupby(churn.PaymentMethod).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.PaymentMethod).mean(),1).plot(kind='bar',title='Average Tenure by Payment Method',
                                                                 color=['red','yellow','pink','skyblue'])
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Payment Method',fontsize=12)
    plt.ylabel('Average Tenure',fontsize=12)
# Out:
# PaymentMethod
# Bank transfer (automatic)    43.656736
# Credit card (automatic)      43.269382
# Electronic check             25.174630
# Mailed check                 21.830025
# Name: tenure, dtype: float64

# %%
# Average tenure by InternetService
print(churn.tenure.groupby(churn.InternetService).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.InternetService).mean(),
        1).plot(kind='bar',title='Average Tenure by Internet Service',color=['green','darkblue','magenta'])
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Internet Service')
    plt.ylabel('Average Tenure')
# Out:
# InternetService
# DSL            32.821561
# Fiber optic    32.917959
# No             30.547182
# Name: tenure, dtype: float64

# %%
# Average Monthly Charges by StreamingMovies
print(churn.tenure.groupby(churn.StreamingMovies).mean())
plt.figure(figsize=(10,6))
a=round(churn.tenure.groupby(churn.StreamingMovies).mean(),
        1).plot(kind='bar',title='Average Tenure by Streaming Movies',color=['gold','silver','blue'])
for i in a.containers:
    a.bar_label(i,fontsize=10)
    plt.xticks(rotation=0)
    plt.xlabel('Streaming Movies',fontsize=12)
    plt.ylabel('Average Tenure',fontsize=12)
# Out:
# StreamingMovies
# No                     24.712388
# No internet service    30.547182
# Yes                    41.197291
# Name: tenure, dtype: float64

# %% [markdown]
# # Hypothesis Testing

# %%
#Test Null Average MonthlyCharges Churn Yes/No Equal
churn.MonthlyCharges.groupby(churn.Churn).mean()
# Out:
# Churn
# No     61.265124
# Yes    74.441332
# Name: MonthlyCharges, dtype: float64

# %%
from scipy.stats import ttest_ind

# %%
# Split
cno=churn[churn.Churn=='No']
cyes=churn[churn.Churn=='Yes']

# %%
ttest_ind(cyes.MonthlyCharges,cno.MonthlyCharges,equal_var=False)
# Since pvalue=8.59244933154705e-73 is less than 0.05,Reject Null
# Out:
# Ttest_indResult(statistic=18.407526676414673, pvalue=8.59244933154705e-73)

# %%
#Test Null Average tenure of Churn Yes/No Equal
churn.tenure.groupby(churn.Churn).mean()
# Out:
# Churn
# No     37.569965
# Yes    17.979133
# Name: tenure, dtype: float64

# %%
ttest_ind(cyes.tenure,cno.tenure,equal_var=False)
# Since pvalue=1.1954945472607151e-232 is less than 0.05,Reject Null
# Out:
# Ttest_indResult(statistic=-34.823818696312976, pvalue=1.1954945472607151e-232)

# %%
#Test Null Average Monthly Charges of different PaymentMethod Equal
churn.MonthlyCharges.groupby(churn.PaymentMethod).mean()
# Out:
# PaymentMethod
# Bank transfer (automatic)    67.192649
# Credit card (automatic)      66.512385
# Electronic check             76.255814
# Mailed check                 43.917060
# Name: MonthlyCharges, dtype: float64

# %%
paybt=churn[churn.PaymentMethod=='Bank transfer (automatic)']
paycd=churn[churn.PaymentMethod=='Credit card (automatic)']
payec=churn[churn.PaymentMethod=='Electronic check']
paymc=churn[churn.PaymentMethod=='Mailed check']

# %%
from scipy.stats import f_oneway

# %%
f_oneway(paybt.MonthlyCharges,paycd.MonthlyCharges,payec.MonthlyCharges,paymc.MonthlyCharges)
# Since pvalue=1.1802197193575694e-267 is less than 0.05,Reject Null
# Out:
# F_onewayResult(statistic=450.3189918892516, pvalue=1.1802197193575694e-267)

# %%
#Test Null Average tenure of different PaymentMethod Equal
f_oneway(paybt.tenure,paycd.tenure,payec.tenure,paymc.tenure)
# Since pvalue=1.503848361277172e-265 is less than 0.05,Reject Null
# Out:
# F_onewayResult(statistic=446.4668862479716, pvalue=1.503848361277172e-265)

# %%
#Test Null No Asssociation between gender & Churn
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(churn.gender,churn.Churn))
# Since pvalue=0.48657873605618596 is less than 0.05,Reject Null
# Out:
# Chi2ContingencyResult(statistic=0.4840828822091383, pvalue=0.48657873605618596, dof=1, expected_freq=array([[2562.38989067,  925.61010933],
#        [2611.61010933,  943.38989067]]))

# %%
#Test Null No Association between SeniorCitizen & Churn 
pd.crosstab(churn.SeniorCitizen,churn.Churn)
# Out:
# Churn            No   Yes
# SeniorCitizen
# 0              4508  1393
# 1               666   476

# %%
chi2_contingency(pd.crosstab(churn.SeniorCitizen,churn.Churn))
# Since pvalue=1.510066805092378e-36 is less than 0.05,Reject Null
# Out:
# Chi2ContingencyResult(statistic=159.42630036838742, pvalue=1.510066805092378e-36, dof=1, expected_freq=array([[4335.05239245, 1565.94760755],
#        [ 838.94760755,  303.05239245]]))

# %% [markdown]
# # Data Pre-Processing

# %%
#LabelEncode data With Churn as Dependent Variable & delete customerID
churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
objcols=churn[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport','StreamingTV', 'StreamingMovies', 'Contract', 
        'PaperlessBilling','PaymentMethod','Churn']]

# %%
numcols=churn[['tenure','MonthlyCharges', 'TotalCharges']]

# %% [markdown]
# # Encoding

# %%
objcols_dummy=pd.get_dummies(objcols.drop('Churn',axis=1))
# Out:
# C:\Users\sujit\AppData\Local\Temp\ipykernel_20136\413636350.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   objcols_dummy=pd.get_dummies(objcols.drop('Churn',axis=1))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
objcols.Churn=le.fit_transform(objcols.Churn)
# Out:
# C:\Users\sujit\AppData\Local\Temp\ipykernel_20136\781276248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   objcols.Churn=le.fit_transform(objcols.Churn)

# %%
objcols.head(50)
# Out:
#     gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0   Female             0     Yes         No           No  No phone service
# 1     Male             0      No         No          Yes                No
# 2     Male             0      No         No          Yes                No
# 3     Male             0      No         No           No  No phone service
# 4   Female             0      No         No          Yes                No
# 5   Female             0      No         No          Yes               Yes
# 6     Male             0      No        Yes          Yes               Yes
# 7   Female             0      No         No           No  No phone service
# 8   Female             0     Yes         No          Yes               Yes
# 9     Male             0      No        Yes          Yes                No
# 10    Male             0     Yes        Yes          Yes                No
# ...

# %%
sns.boxplot(numcols)
# Out:
# <Axes: >

# %%
# Checking Multicollinearity
sns.heatmap(numcols.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
numcols=scaler.fit_transform(numcols)

# %%
numcols=pd.DataFrame(numcols,columns=['tenure','MonthlyCharges', 'TotalCharges'])

# %% [markdown]
# # Combining The Data

# %%
cleandf=pd.concat([numcols,objcols_dummy,objcols.Churn],axis=1)

# %%
cleandf.head()
# Out:
#      tenure  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0 -1.277445       -1.160323     -0.994242              1            0
# 1  0.066327       -0.259629     -0.173244              0            1
# 2 -1.236724       -0.362660     -0.959674              0            1
# 3  0.514251       -0.746535     -0.194766              0            1
# 4 -1.236724        0.197365     -0.940470              1            0
#
#    SeniorCitizen_0  SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  \
# 0                1                0           0            1              1
# 1                1                0           1            0              1
# 2                1                0           1            0              1
# 3                1                0           1            0              1
# 4                1                0           1            0              1
#
#    ...  Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %% [markdown]
# # Splitting The Data Into X & y

# %%
X=cleandf.drop('Churn',axis=1)
y=cleandf.Churn

# %% [markdown]
# # With Churn as Dependent Variable &delete customerID, Build the following

# %% [markdown]
# # Models with Confusion Matrix & Accuracy & AUC Curve

# %% [markdown]
# # a) Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression(max_iter=1000)

# %%
logitmodel=reg.fit(X,y)

# %%
logitmodel.score(X,y)
# Out:
# 0.8069004685503337

# %%
logitpredict=logitmodel.predict(X)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,RocCurveDisplay,classification_report

# %%
ConfusionMatrixDisplay.from_predictions(y,logitpredict)

# %%
RocCurveDisplay.from_predictions(y,logitpredict)

# %%
print(classification_report(y,logitpredict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      5174
#            1       0.66      0.55      0.60      1869
#
#     accuracy                           0.81      7043
#    macro avg       0.76      0.73      0.74      7043
# weighted avg       0.80      0.81      0.80      7043

# %%
np.round(logitmodel.predict_proba(X),2)
# Out:
# array([[0.37, 0.63],
#        [0.96, 0.04],
#        [0.71, 0.29],
#        ...,
#        [0.58, 0.42],
#        [0.3 , 0.7 ],
#        [0.95, 0.05]])

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(reg,X,y)
# Out:
# array([0.80340667, 0.8105039 , 0.78992193, 0.81036932, 0.8046875 ])

# %%
np.mean([0.80340667, 0.8105039 , 0.78992193, 0.81036932, 0.8046875 ])
# Out:
# 0.803777864

# %%
pd.DataFrame(logitmodel.coef_,columns=X.columns).T
# Out:
#                                                 0
# tenure                                  -1.408415
# MonthlyCharges                          -0.303562
# TotalCharges                             0.667715
# gender_Female                            0.012247
# gender_Male                             -0.010809
# SeniorCitizen_0                         -0.106351
# SeniorCitizen_1                          0.107789
# Partner_No                               0.001943
# Partner_Yes                             -0.000505
# Dependents_No                            0.078195
# Dependents_Yes                          -0.076756
# PhoneService_No                          0.076142
# PhoneService_Yes                        -0.074704
# MultipleLines_No                        -0.186197
# MultipleLines_No phone service           0.076142
# MultipleLines_Yes                        0.111492
# InternetService_DSL                     -0.432930
# InternetService_Fiber optic              0.570508
# ...

# %% [markdown]
# # b) DecisionTree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree=DecisionTreeClassifier(max_depth=9)

# %%
treemodel=tree.fit(X,y)

# %%
treemodel.score(X,y)
# Out:
# 0.8482180888825784

# %%
treepred=treemodel.predict(X)

# %%
print(classification_report(y,treepred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      5174
#            1       0.73      0.67      0.70      1869
#
#     accuracy                           0.85      7043
#    macro avg       0.81      0.79      0.80      7043
# weighted avg       0.84      0.85      0.85      7043

# %%
ConfusionMatrixDisplay.from_predictions(y,treepred)

# %%
RocCurveDisplay.from_predictions(y,treepred)

# %%
cross_val_score(tree,X,y)
# Out:
# array([0.76863023, 0.78424414, 0.75301632, 0.75852273, 0.78409091])

# %%
np.mean([0.76863023, 0.78424414, 0.75301632, 0.75852273, 0.78409091])
# Out:
# 0.769700866

# %% [markdown]
# # c) RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=1000)

# %%
rfmodel=rf.fit(X,y)

# %%
rfmodel.score(X,y)
# Out:
# 0.9974442709072838

# %%
rfpred=rfmodel.predict(X)

# %%
print(classification_report(y,rfpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5174
#            1       0.99      1.00      1.00      1869
#
#     accuracy                           1.00      7043
#    macro avg       1.00      1.00      1.00      7043
# weighted avg       1.00      1.00      1.00      7043

# %%
ConfusionMatrixDisplay.from_predictions(y,rfpred)

# %%
RocCurveDisplay.from_predictions(y,rfpred)

# %%
cross_val_score(rf,X,y)
# Out:
# array([0.79914833, 0.79134138, 0.77004968, 0.79616477, 0.80042614])

# %%
np.mean([0.79914833, 0.79134138, 0.77004968, 0.79616477, 0.80042614])
# Out:
# 0.7914260599999999

# %% [markdown]
# # d) GradientBoosting Classifer

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier(n_estimators=1000)

# %%
gbmodel=gb.fit(X,y)

# %%
gbmodel.score(X,y)
# Out:
# 0.9075677978134318

# %%
gbpred=gbmodel.predict(X)

# %%
print(classification_report(y,gbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      5174
#            1       0.87      0.77      0.82      1869
#
#     accuracy                           0.91      7043
#    macro avg       0.89      0.86      0.88      7043
# weighted avg       0.91      0.91      0.91      7043

# %%
RocCurveDisplay.from_predictions(y,gbpred)

# %%
ConfusionMatrixDisplay.from_predictions(y,gbpred)

# %%
cross_val_score(gb,X,y)
# Out:
# array([0.78069553, 0.79276082, 0.76650106, 0.77556818, 0.79332386])

# %%
np.mean([0.78069553, 0.7920511 , 0.76650106, 0.77556818, 0.79048295])
# Out:
# 0.781059764

# %% [markdown]
# # e) BernouliNB

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
nb=BernoulliNB()

# %%
nbmodel=nb.fit(X,y)

# %%
nbmodel.score(X,y)
# Out:
# 0.7254011074826069

# %%
nbpred=nbmodel.predict(X)

# %%
print(classification_report(y,nbpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79      5174
#            1       0.49      0.81      0.61      1869
#
#     accuracy                           0.73      7043
#    macro avg       0.70      0.75      0.70      7043
# weighted avg       0.80      0.73      0.74      7043

# %%
ConfusionMatrixDisplay.from_predictions(y,nbpred)

# %%
RocCurveDisplay.from_predictions(y,nbpred)

# %%
cross_val_score(nb,X,y)
# Out:
# array([0.73669269, 0.72959546, 0.71823989, 0.72017045, 0.71590909])

# %%
np.mean([0.73669269, 0.72959546, 0.71823989, 0.72017045, 0.71590909])
# Out:
# 0.724121516

# %% [markdown]
# # f) KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
knn=KNeighborsClassifier()

# %%
k_range=list(range(1,21))
param_grid=dict(n_neighbors=k_range)
grid=GridSearchCV(knn,param_grid,cv=3)

# %%
grid_search=grid.fit(X,y)
# Out:
# C:\Users\sujit\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
grid_search.score(X,y)
# Out:
# C:\Users\sujit\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.8134317762317195

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 20}

# %%
grid_search.best_score_
# Out:
# 0.7922756877640745

# %%
gridpred=grid_search.predict(X)
# Out:
# C:\Users\sujit\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
print(classification_report(y,gridpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      5174
#            1       0.68      0.57      0.62      1869
#
#     accuracy                           0.81      7043
#    macro avg       0.77      0.73      0.75      7043
# weighted avg       0.81      0.81      0.81      7043

# %%
ConfusionMatrixDisplay.from_predictions(y,gridpred)

# %%
RocCurveDisplay.from_predictions(y,gridpred)

# %%
cross_val_score(knn,X,y)
# Out:
# C:\Users\sujit\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
np.mean([0.78069553, 0.7707594 , 0.75727466, 0.77130682, 0.77840909])
# Out:
# 0.7716891

# %% [markdown]
# # g) Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
svcmodel=SVC().fit(X,y)

# %%
svcmodel.score(X,y)
# Out:
# 0.816555445122817

# %%
svcpred=svcmodel.predict(X)

# %%
print(classification_report(y,svcpred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      5174
#            1       0.71      0.52      0.60      1869
#
#     accuracy                           0.82      7043
#    macro avg       0.78      0.72      0.74      7043
# weighted avg       0.81      0.82      0.81      7043

# %%
ConfusionMatrixDisplay.from_predictions(y,svcpred)

# %%
RocCurveDisplay.from_predictions(y,svcpred)

# %%
cross_val_score(SVC(),X,y)
# Out:
# array([0.80198722, 0.8105039 , 0.78211498, 0.80255682, 0.80042614])

# %%
np.mean([0.80198722, 0.8105039 , 0.78211498, 0.80255682, 0.80042614])
# Out:
# 0.7995178119999999
